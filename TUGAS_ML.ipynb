# %% [markdown]
# <a href="https://colab.research.google.com/github/tifasabina1/MesinLearningFafah/blob/main/TUGAS_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Latifah Ainun Sabina
#H081211025

# %%
#Import Library

import pandas as pd
import os

# %%
#Import data dari drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Data
data_sales = pd.read_csv('/content/drive/MyDrive/dataset/Sales.csv')
data_sales
# Out:
#        Brands          Models         Colors Memory                Storage  \
# 0     SAMSUNG    GALAXY M31S    Mirage Black   8 GB                 128 GB
# 1       Nokia             3.2          Steel   2 GB                  16 GB
# 2      realme             C2   Diamond Black   2 GB                    NaN
# 3     Infinix          Note 5       Ice Blue   4 GB                  64 GB
# 4       Apple      iPhone 11           Black    4GB                  64 GB
# ...       ...             ...            ...    ...                    ...
# 3109     POCO       M4 Pro 5G      Cool Blue   6 GB                 128 GB
# 3110    Nokia             225          Black    NaN  Expandable Upto 32 GB
# 3111    Apple      iPhone SE           White   2 GB                 128 GB
# 3112    Apple  iPhone 13 Pro            Gold   6 GB                 128 GB
# 3113   GIONEE             F9            Blue   3 GB                  32 GB
#
# ...

# %%
# @title Rating vs Selling Price

from matplotlib import pyplot as plt
data_sales.plot(kind='scatter', x='Rating', y='Selling Price', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#Melihat 10 data teratas
data_sales.head(10)
# Out:
#     Brands             Models           Colors  Memory Storage Camera  Rating  \
# 0  SAMSUNG       GALAXY M31S      Mirage Black    8 GB  128 GB    Yes     4.3
# 1    Nokia                3.2            Steel    2 GB   16 GB    Yes     3.8
# 2   realme                C2     Diamond Black    2 GB     NaN    Yes     4.4
# 3  Infinix             Note 5         Ice Blue    4 GB   64 GB    Yes     4.2
# 4    Apple         iPhone 11             Black     4GB   64 GB    Yes     4.6
# 5   GIONEE               L800            Black    8 MB   16 MB    Yes     4.0
# 6    Apple    iPhone 13 Mini              Pink    6 GB  512 GB    Yes     NaN
# 7    Apple         iPhone XR             Coral    3 GB   64 GB    Yes     4.6
# 8  SAMSUNG         Galaxy E5             Brown  1.5 GB   16 GB    Yes     4.2
# 9   Xiaomi  Redmi Note 11T 5G  Aquamarine Blue    8 GB  128 GB    Yes     4.3
#
#    Selling Price  Original Price                    Mobile  Discount  \
# ...

# %%
#Melihat tipe data
data_sales.dtypes
# Out:
# Brands                  object
# Models                  object
# Colors                  object
# Memory                  object
# Storage                 object
# Camera                  object
# Rating                 float64
# Selling Price            int64
# Original Price           int64
# Mobile                  object
# Discount                 int64
# discount percentage    float64
# dtype: object

# %%
#Menghapus salah satu kolom
datanostorage = data_sales.drop(data_sales.columns[4],axis=1)
datanostorage
# Out:
#        Brands          Models         Colors Memory Camera  Rating  \
# 0     SAMSUNG    GALAXY M31S    Mirage Black   8 GB    Yes     4.3
# 1       Nokia             3.2          Steel   2 GB    Yes     3.8
# 2      realme             C2   Diamond Black   2 GB    Yes     4.4
# 3     Infinix          Note 5       Ice Blue   4 GB    Yes     4.2
# 4       Apple      iPhone 11           Black    4GB    Yes     4.6
# ...       ...             ...            ...    ...    ...     ...
# 3109     POCO       M4 Pro 5G      Cool Blue   6 GB    Yes     4.4
# 3110    Nokia             225          Black    NaN    Yes     3.6
# 3111    Apple      iPhone SE           White   2 GB    Yes     4.5
# 3112    Apple  iPhone 13 Pro            Gold   6 GB    Yes     NaN
# 3113   GIONEE             F9            Blue   3 GB    Yes     4.2
#
#       Selling Price  Original Price                Mobile  Discount  \
# 0             19330           20999  SAMSUNG GALAXY M31S       1669
# ...

# %%
#Statistika Deskriptif
data_sales.describe()
# Out:
#             Rating  Selling Price  Original Price      Discount  \
# count  2970.000000    3114.000000     3114.000000   3114.000000
# mean      4.243098   26436.625562    28333.473025   1896.847463
# std       0.271991   30066.892622    31525.599889   5337.126176
# min       2.300000    1000.000000     1000.000000  -8000.000000
# 25%       4.100000    9990.000000    10030.250000      0.000000
# 50%       4.300000   15000.000000    16889.500000      0.000000
# 75%       4.400000   28999.000000    31500.000000   2000.000000
# max       5.000000  179900.000000   189999.000000  75000.000000
#
#        discount percentage
# count          3114.000000
# mean              6.086788
# std              11.106776
# min            -160.320641
# 25%               0.000000
# 50%               0.000000
# 75%               9.836388
# max              70.610305

# %%
#Hubungan antarvariabel menggunakan korelasi
data_sales.loc[:,"Rating":].corr()
# Out:
# <ipython-input-14-3023a9c2160e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_sales.loc[:,"Rating":].corr()
#                        Rating  Selling Price  Original Price  Discount  \
# Rating               1.000000       0.458545        0.451354  0.111249
# Selling Price        0.458545       1.000000        0.986097  0.191189
# Original Price       0.451354       0.986097        1.000000  0.351638
# Discount             0.111249       0.191189        0.351638  1.000000
# discount percentage  0.052521      -0.066082        0.049209  0.662945
#
#                      discount percentage
# Rating                          0.052521
# Selling Price                  -0.066082
# Original Price                  0.049209
# Discount                        0.662945
# discount percentage             1.000000

# %% [markdown]
# DENGAN API

# %%
! pip install -q kaggle

# %%
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !cp kaggle.json ~/.kaggle

# %%
# !chmood 600 ~/.kaggle/kaggle.json
# Out:
# /bin/bash: line 1: chmood: command not found

# %%
! kaggle datasets list
# Out:
# ...
# ref                                             title                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------  ---------------------------------  -----  -------------------  -------------  ---------  ---------------
# syedanwarafridi/vehicle-sales-data              Vehicle Sales Data                  19MB  2024-02-21 20:16:17           6295        104  1.0
# tarunrm09/climate-change-indicators             Climate change Indicators           34KB  2024-02-22 08:53:54           3035         72  1.0
# nelgiriyewithana/apple-quality                  Apple Quality                      170KB  2024-01-11 14:31:07          25192        535  1.0
# mikhail1681/walmart-sales                       Walmart Sales                      122KB  2024-02-13 17:35:56           5364         82  1.0
# ...

# %%
# !kaggle datasets download -d yaminh/smartphone-sale-dataset
# Out:
# ...
#   0% 0.00/65.3k [00:00<?, ?B/s]
# 100% 65.3k/65.3k [00:00<00:00, 41.7MB/s]
